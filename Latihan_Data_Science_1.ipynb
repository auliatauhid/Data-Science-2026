# %% [markdown]
# <a href="https://colab.research.google.com/github/auliatauhid/Data-Science-2026/blob/main/Latihan_Data_Science_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aulia Tauhid Akbar - 250401020136 - Data Science IF405

# %%
#Output sederhana
print("Hello world")
# Out:
# Hello world

# %%
#Variable dan Data Type
nama = "Aulia Tauhid Akbar"
angkatan = 2026
prodi = "PJJ Informatika"
print (nama)
print (angkatan)
print (f"Halo nama saya {nama} dari angkatan {angkatan}")
# Out:
# Aulia Tauhid Akbar
# 2026
# Halo nama saya Aulia Tauhid Akbar dari angkatan 2026

# %%
#List
tools = ["Python", "Google Collabs", "Jupiter notebook", "Github"]

for i in tools:
  print(i)
# Out:
# Python
# Google Collabs
# Jupiter notebook
# Github

# %%
#Fungsi
def perkenalan(nama, prodi, angkatan):
  return print (f"Halo nama saya {nama} jurusan {prodi} dari angkatan {angkatan}")

perkenalan("John", "Informatika", 2026)
# Out:
# Halo nama saya John jurusan Informatika dari angkatan 2026

# %% [markdown]
# **Kesimpulan**
#
# Apa yang dipelajari:
# Program ini mencakup fondasi dasar Python — output dengan print(), tipe data string dan integer, f-string untuk formatting teks, struktur data list dengan iterasi for, dan pembuatan fungsi dengan parameter menggunakan def.
# Temuan utama:
# Semua kode berjalan dengan benar dan outputnya sesuai ekspektasi. Penggunaan f-string sudah tepat dan efektif. Fungsi perkenalan() sudah modular dan bisa dipanggil ulang dengan data berbeda, yang menunjukkan pemahaman awal tentang reusability kode.
# Keterbatasan / Pertanyaan yang muncul:
#
# Fungsi perkenalan() langsung memanggil print() di dalam return — lebih baik fungsi me-return string-nya saja, lalu print() dipanggil di luar agar lebih fleksibel.
# Belum ada validasi input (misalnya, bagaimana jika angkatan diisi string?).
# List tools hanya ditampilkan, belum dimanipulasi — muncul pertanyaan: bagaimana cara menambah, menghapus, atau mencari item di dalamnya?
# Langkah selanjutnya yang natural: dictionary, kondisional (if/else), dan penanganan error (try/except).
